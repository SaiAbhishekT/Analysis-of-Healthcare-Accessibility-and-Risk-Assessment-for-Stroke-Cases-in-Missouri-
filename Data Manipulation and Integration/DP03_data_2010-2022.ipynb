# %%
import pandas as pd, numpy as np , os , gc

# %%
file_list = os.listdir()

# %%
file_list
# Out:
# ['ACSDP5Y2022.DP03-Data.csv',
#  'ACSDP5Y2022.DP03-Column-Metadata.csv',
#  'ACSDP5Y2022.DP03-Table-Notes.txt',
#  'ACSDP5Y2021.DP03-Data.csv',
#  'ACSDP5Y2021.DP03-Column-Metadata.csv',
#  'ACSDP5Y2021.DP03-Table-Notes.txt',
#  'ACSDP5Y2020.DP03-Data.csv',
#  'ACSDP5Y2020.DP03-Column-Metadata.csv',
#  'ACSDP5Y2020.DP03-Table-Notes.txt',
#  'ACSDP5Y2019.DP03-Data.csv',
#  'ACSDP5Y2019.DP03-Column-Metadata.csv',
#  'ACSDP5Y2019.DP03-Table-Notes.txt',
#  'ACSDP5Y2018.DP03-Data.csv',
#  'ACSDP5Y2018.DP03-Column-Metadata.csv',
#  'ACSDP5Y2018.DP03-Table-Notes.txt',
#  'ACSDP5Y2017.DP03-Data.csv',
#  'ACSDP5Y2017.DP03-Column-Metadata.csv',
#  'ACSDP5Y2017.DP03-Table-Notes.txt',
#  'ACSDP5Y2016.DP03-Data.csv',
#  'ACSDP5Y2016.DP03-Column-Metadata.csv',
#  'ACSDP5Y2016.DP03-Table-Notes.txt',
#  'ACSDP5Y2015.DP03-Data.csv',
#  'ACSDP5Y2015.DP03-Column-Metadata.csv',
#  'ACSDP5Y2015.DP03-Table-Notes.txt',
#  'ACSDP5Y2014.DP03-Data.csv',
#  'ACSDP5Y2014.DP03-Column-Metadata.csv',
# ...

# %%
dp03list = [i for i in file_list if 'DP03' in i]
dp04list = [i for i in file_list if 'DP04' in i]

# %%
dp03list
# Out:
# ['ACSDP5Y2022.DP03-Data.csv',
#  'ACSDP5Y2022.DP03-Column-Metadata.csv',
#  'ACSDP5Y2022.DP03-Table-Notes.txt',
#  'ACSDP5Y2021.DP03-Data.csv',
#  'ACSDP5Y2021.DP03-Column-Metadata.csv',
#  'ACSDP5Y2021.DP03-Table-Notes.txt',
#  'ACSDP5Y2020.DP03-Data.csv',
#  'ACSDP5Y2020.DP03-Column-Metadata.csv',
#  'ACSDP5Y2020.DP03-Table-Notes.txt',
#  'ACSDP5Y2019.DP03-Data.csv',
#  'ACSDP5Y2019.DP03-Column-Metadata.csv',
#  'ACSDP5Y2019.DP03-Table-Notes.txt',
#  'ACSDP5Y2018.DP03-Data.csv',
#  'ACSDP5Y2018.DP03-Column-Metadata.csv',
#  'ACSDP5Y2018.DP03-Table-Notes.txt',
#  'ACSDP5Y2017.DP03-Data.csv',
#  'ACSDP5Y2017.DP03-Column-Metadata.csv',
#  'ACSDP5Y2017.DP03-Table-Notes.txt',
#  'ACSDP5Y2016.DP03-Data.csv',
#  'ACSDP5Y2016.DP03-Column-Metadata.csv',
#  'ACSDP5Y2016.DP03-Table-Notes.txt',
#  'ACSDP5Y2015.DP03-Data.csv',
#  'ACSDP5Y2015.DP03-Column-Metadata.csv',
#  'ACSDP5Y2015.DP03-Table-Notes.txt',
#  'ACSDP5Y2014.DP03-Data.csv',
#  'ACSDP5Y2014.DP03-Column-Metadata.csv',
# ...

# %%
df = pd.read_csv('ACSDP5Y2022.DP03-Data.csv'  )
columns = df.iloc[0]
df.head()
# Out:
#            GEO_ID                       NAME  \
# 0       Geography       Geographic Area Name
# 1  0500000US29001     Adair County, Missouri
# 2  0500000US29003    Andrew County, Missouri
# 3  0500000US29005  Atchison County, Missouri
# 4  0500000US29007   Audrain County, Missouri
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                              21228
# 2                                              14336
# 3                                               4289
# 4                                              19938
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                                127
# 2                                                122
# 3                                                 36
# 4                                                104
#
# ...

# %%
columns = pd.DataFrame(columns).reset_index()
columns
# Out:
#             index                                                  0
# 0          GEO_ID                                          Geography
# 1            NAME                               Geographic Area Name
# 2      DP03_0001E  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 3      DP03_0001M  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 4      DP03_0002E  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# ..            ...                                                ...
# 546   DP03_0136PE  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 547   DP03_0136PM  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 548   DP03_0137PE  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 549   DP03_0137PM  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 550  Unnamed: 550                                                NaN
#
# [551 rows x 2 columns]

# %%
columns = columns[(columns[0].str.contains('Margin of Error') != True)]
columns = columns[(columns['index'].str.contains('Unnamed')!= True)]
columns[0] = columns[0].str.replace('INCOME AND BENEFITS (IN 2022 INFLATION-ADJUSTED DOLLARS)', 'INCOME AND BENEFITS ')
columns
# Out:
#            index                                                  0
# 0         GEO_ID                                          Geography
# 1           NAME                               Geographic Area Name
# 2     DP03_0001E  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 4     DP03_0002E  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 6     DP03_0003E  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# ..           ...                                                ...
# 540  DP03_0133PE  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 542  DP03_0134PE  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 544  DP03_0135PE  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 546  DP03_0136PE  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 548  DP03_0137PE  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
#
# [276 rows x 2 columns]

# %%
#cols = [col for col in df.columns if 'Margin of Error' not in col]
#cols = [col for col in cols if 'Unnamed' not in col]
#cols
#df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2022 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
#df['Margin of Error' in df.columns]

# %%
comb_df = pd.DataFrame()
flag = 0 
for i in dp03list:
    if 'DP03-Data.csv' in i:
        #print(i[7:11], ':' , '','\n')
        df = pd.read_csv(i )
        df = df.iloc[1:,:]
        print(i[7:11], ':' , df.shape,'\n')
        #col_name = 'Column Name'+'_'+i[7:11]
        #df.rename({'Column Name' : col_name},axis = 1 , inplace = True)
        df['Year'] =  i[7:11]
        #cols = [col for col in df.columns if 'M' not in col]
        #cols = [col for col in df.columns if 'PM' not in col]        
        cols = [col for col in df.columns if 'Unnamed' not in col]
        #cols = []
        df = df[cols]
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2022 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2021 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2020 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2018 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2015 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2014 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2013 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2012 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2011 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        #df = df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2010 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))
        flag+=1
        if (flag == 1):
            comb_df = df.copy()
        else:
            #comb_df = pd.merge(comb_df , df , on = 'Label' , how ='left')
            comb_df = pd.concat([comb_df , df ] ,axis = 0, sort = False)
            print('Combined Shape: ',comb_df.shape , '\n')
            print(len(list(set(comb_df.columns) - set(df.columns))) , '\n')
# Out:
# 2022 : (115, 551)
#
# 2021 : (115, 551)
#
# Combined Shape:  (230, 551)
#
# 0
#
# 2020 : (115, 551)
#
# Combined Shape:  (345, 551)
#
# 0
#
# 2019 : (115, 551)
#
# Combined Shape:  (460, 551)
#
# 0
#
# 2018 : (115, 551)
#
# Combined Shape:  (575, 551)
#
# 0
#
# 2017 : (115, 551)
#
# Combined Shape:  (690, 551)
#
# 0
#
# 2016 : (115, 551)
#
# Combined Shape:  (805, 551)
#
# 0
#
# 2015 : (115, 551)
#
# Combined Shape:  (920, 551)
#
# 0
#
# 2014 : (115, 551)
#
# Combined Shape:  (1035, 551)
#
# 0
#
# 2013 : (115, 551)
#
# Combined Shape:  (1150, 551)
#
# 0
#
# 2012 : (115, 551)
#
# Combined Shape:  (1265, 551)
#
# 0
#
# 2011 : (115, 551)
#
# Combined Shape:  (1380, 551)
#
# 0
#
# 2010 : (115, 551)
#
# Combined Shape:  (1495, 551)
#
# 0

# %%
comb_df.head()
# Out:
#            GEO_ID                       NAME DP03_0001E DP03_0001M DP03_0002E  \
# 1  0500000US29001     Adair County, Missouri      21228        127      10797
# 2  0500000US29003    Andrew County, Missouri      14336        122       9052
# 3  0500000US29005  Atchison County, Missouri       4289         36       2614
# 4  0500000US29007   Audrain County, Missouri      19938        104      11536
# 5  0500000US29009     Barry County, Missouri      27746        131      15502
#
#   DP03_0002M DP03_0003E DP03_0003M DP03_0004E DP03_0004M  ... DP03_0133PM  \
# 1        514      10797        514      10207        483  ...         3.0
# 2        293       8943        301       8572        298  ...         1.8
# 3         99       2614         99       2546         99  ...         1.9
# 4        411      11526        411      11077        428  ...         1.9
# 5        599      15484        600      14930        628  ...         1.9
#
# ...

# %%
comb_df.describe()
# Out:
#                 GEO_ID                      NAME DP03_0001E DP03_0001M  \
# count             1495                      1495       1495       1495
# unique             115                       115       1454        321
# top     0500000US29199  Hickory County, Missouri       6246         39
# freq                13                        13          3         20
#
#        DP03_0002E DP03_0002M DP03_0003E DP03_0003M DP03_0004E DP03_0004M  ...  \
# count        1495       1495       1495       1495       1495       1495  ...
# unique       1450        737       1435        733       1440        734  ...
# top          7733        230       5326        302       8906        289  ...
# freq            2          8          3          9          3          8  ...
#
#        DP03_0133PM DP03_0134PE DP03_0134PM DP03_0135PE DP03_0135PM  \
# count         1495        1495        1495        1495        1495
# unique          50         245          62         183          83
# ...

# %%
comb_df.columns.to_list()
# Out:
# ['GEO_ID',
#  'NAME',
#  'DP03_0001E',
#  'DP03_0001M',
#  'DP03_0002E',
#  'DP03_0002M',
#  'DP03_0003E',
#  'DP03_0003M',
#  'DP03_0004E',
#  'DP03_0004M',
#  'DP03_0005E',
#  'DP03_0005M',
#  'DP03_0006E',
#  'DP03_0006M',
#  'DP03_0007E',
#  'DP03_0007M',
#  'DP03_0008E',
#  'DP03_0008M',
#  'DP03_0009E',
#  'DP03_0009M',
#  'DP03_0010E',
#  'DP03_0010M',
#  'DP03_0011E',
#  'DP03_0011M',
#  'DP03_0012E',
#  'DP03_0012M',
#  'DP03_0013E',
#  'DP03_0013M',
#  'DP03_0014E',
#  'DP03_0014M',
#  'DP03_0015E',
#  'DP03_0015M',
#  'DP03_0016E',
#  'DP03_0016M',
#  'DP03_0017E',
#  'DP03_0017M',
#  'DP03_0018E',
#  'DP03_0018M',
#  'DP03_0019E',
#  'DP03_0019M',
#  'DP03_0020E',
#  'DP03_0020M',
#  'DP03_0021E',
#  'DP03_0021M',
#  'DP03_0022E',
#  'DP03_0022M',
#  'DP03_0023E',
#  'DP03_0023M',
#  'DP03_0024E',
#  'DP03_0024M',
#  'DP03_0025E',
#  'DP03_0025M',
#  'DP03_0026E',
#  'DP03_0026M',
#  'DP03_0027E',
#  'DP03_0027M',
#  'DP03_0028E',
#  'DP03_0028M',
#  'DP03_0029E',
# ...

# %%
columns_map = dict(zip(columns['index'], columns[0]))

# Rename columns based on the mapping dictionary
comb_df = comb_df.rename(columns=columns_map)
comb_df = comb_df.drop(columns=comb_df.filter(regex='^DP03').columns)
comb_df.columns
# Out:
# Index(['Geography', 'Geographic Area Name',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Armed Forces',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!Not in labor force',
#        'Estimate!!EMPLOYMENT STATUS!!Civilian labor force',
#        ...
#        'Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Under 18 years',
# ...

# %%
comb_df = comb_df.rename(columns=lambda x: x.replace('INCOME AND BENEFITS (IN 2022 INFLATION-ADJUSTED DOLLARS)','INCOME AND BENEFITS '))

# %%
comb_df.to_csv('dp03_combined.csv')

# %%
comb_df.iloc[:,2:276].columns
# Out:
# Index(['Estimate!!EMPLOYMENT STATUS!!Population 16 years and over',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Armed Forces',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!Not in labor force',
#        'Estimate!!EMPLOYMENT STATUS!!Civilian labor force',
#        'Estimate!!EMPLOYMENT STATUS!!Civilian labor force!!Unemployment Rate',
#        'Estimate!!EMPLOYMENT STATUS!!Females 16 years and over',
#        ...
# ...

# %%
import re
# def is_numeric(value):
#     return isinstance(value, (int, float))
columns = list(comb_df.iloc[:,2:276].columns)

# Replace non-numeric values with NaN for selected columns
#comb_df[columns] = comb_df[columns].applymap(lambda x: x if is_numeric(x) else np.nan)
def clean_text(text):
    return re.sub(r'[^0-9.]', '', str(text))

# Apply the function to each element in the dataframe
comb_df[columns] = comb_df[columns].applymap(clean_text)

#comb_df[columns] = comb_df[columns].astype(float)

# %%
comb_df[columns] = comb_df[columns].apply(pd.to_numeric, errors='coerce')

# %%
comb_df.head()
# Out:
#         Geography       Geographic Area Name  \
# 1  0500000US29001     Adair County, Missouri
# 2  0500000US29003    Andrew County, Missouri
# 3  0500000US29005  Atchison County, Missouri
# 4  0500000US29007   Audrain County, Missouri
# 5  0500000US29009     Barry County, Missouri
#
#    Estimate!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 1                                              21228
# 2                                              14336
# 3                                               4289
# 4                                              19938
# 5                                              27746
#
#    Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                              10797
# 2                                               9052
# 3                                               2614
# 4                                              11536
# 5                                              15502
#
# ...

# %%
comb_df.isna().sum() / len(comb_df)
# Out:
# Geography                                                                                                                                                                                                                                                                                             0.000000
# Geographic Area Name                                                                                                                                                                                                                                                                                  0.000000
# Estimate!!EMPLOYMENT STATUS!!Population 16 years and over                                                                                                                                                                                                                                             0.000000
# ...

# %%
nan_percentage = (comb_df.isna().sum() / len(comb_df)) * 100

# Print column names where the percentage exceeds 70%
columns_70_nan = nan_percentage[nan_percentage > 70].index
print(columns_70_nan)
# Out:
# Index(['Estimate!!EMPLOYMENT STATUS!!Civilian labor force!!Unemployment Rate',
#        'Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families',
#        'Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!With related children of the householder under 18 years',
#        'Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!With related children of the householder under 18 years!!With related children of the householder under 5 years only',
#        'Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!Married couple families',
# ...

# %%
comb_df1 = comb_df.drop(columns=columns_70_nan)
comb_df1.columns
# Out:
# Index(['Geography', 'Geographic Area Name',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Armed Forces',
#        'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!Not in labor force',
#        'Estimate!!EMPLOYMENT STATUS!!Civilian labor force',
#        ...
#        'Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Under 18 years',
# ...

# %%
col_df = pd.DataFrame(comb_df1.columns.T)

# %%
col_df
# Out:
#                                                      0
# 0                                            Geography
# 1                                 Geographic Area Name
# 2    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 3    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 4    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 5    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 6    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 7    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 8    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 9    Estimate!!EMPLOYMENT STATUS!!Civilian labor force
# 10   Estimate!!EMPLOYMENT STATUS!!Females 16 years ...
# 11   Estimate!!EMPLOYMENT STATUS!!Females 16 years ...
# 12   Estimate!!EMPLOYMENT STATUS!!Females 16 years ...
# 13   Estimate!!EMPLOYMENT STATUS!!Females 16 years ...
# 14   Estimate!!EMPLOYMENT STATUS!!Own children of t...
# 15   Estimate!!EMPLOYMENT STATUS!!Own children of t...
# ...

# %%
col_df[['1', '2' , '3' , '4' , '5']] = col_df[0].str.split('!!',n=4,expand=True)

# %%
col_df
# Out:
#                                                      0                     1  \
# 0                                            Geography             Geography
# 1                                 Geographic Area Name  Geographic Area Name
# 2    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 3    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 4    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 5    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 6    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 7    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 8    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 9    Estimate!!EMPLOYMENT STATUS!!Civilian labor force              Estimate
# 10   Estimate!!EMPLOYMENT STATUS!!Females 16 years ...              Estimate
# ...

# %%
col_df.to_csv('DP03_categries.csv')

# %%
col_df
# Out:
#                                                      0                     1  \
# 0                                            Geography             Geography
# 1                                 Geographic Area Name  Geographic Area Name
# 2    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 3    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 4    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 5    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 6    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 7    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 8    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...              Estimate
# 9    Estimate!!EMPLOYMENT STATUS!!Civilian labor force              Estimate
# 10   Estimate!!EMPLOYMENT STATUS!!Females 16 years ...              Estimate
# ...

# %%
col_df['2'].unique()
# Out:
# array([None, 'EMPLOYMENT STATUS', 'COMMUTING TO WORK', 'OCCUPATION',
#        'INDUSTRY', 'CLASS OF WORKER', 'INCOME AND BENEFITS ',
#        'HEALTH INSURANCE COVERAGE',
#        'PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL'],
#       dtype=object)

# %%
catlist =  ['EMPLOYMENT STATUS', 
         'INCOME AND BENEFITS ',
       'HEALTH INSURANCE COVERAGE',
       'PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL']

# %%
col_df = col_df[col_df['2'].isin(catlist)]
col_df
# Out:
#                                                      0         1  \
# 2    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...  Estimate
# 3    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...  Estimate
# 4    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...  Estimate
# 5    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...  Estimate
# 6    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...  Estimate
# 7    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...  Estimate
# 8    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...  Estimate
# 9    Estimate!!EMPLOYMENT STATUS!!Civilian labor force  Estimate
# 10   Estimate!!EMPLOYMENT STATUS!!Females 16 years ...  Estimate
# 11   Estimate!!EMPLOYMENT STATUS!!Females 16 years ...  Estimate
# 12   Estimate!!EMPLOYMENT STATUS!!Females 16 years ...  Estimate
# 13   Estimate!!EMPLOYMENT STATUS!!Females 16 years ...  Estimate
# 14   Estimate!!EMPLOYMENT STATUS!!Own children of t...  Estimate
# ...

# %%
col_df[col_df['2'] == 'EMPLOYMENT STATUS'][0].to_list()
#ol_df.columns
# Out:
# ['Estimate!!EMPLOYMENT STATUS!!Population 16 years and over',
#  'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force',
#  'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force',
#  'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed',
#  'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Unemployed',
#  'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Armed Forces',
#  'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!Not in labor force',
#  'Estimate!!EMPLOYMENT STATUS!!Civilian labor force',
#  'Estimate!!EMPLOYMENT STATUS!!Females 16 years and over',
#  'Estimate!!EMPLOYMENT STATUS!!Females 16 years and over!!In labor force',
#  'Estimate!!EMPLOYMENT STATUS!!Females 16 years and over!!In labor force!!Civilian labor force',
# ...

# %%
emp_list = [
 'Percent!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force',

 'Percent!!EMPLOYMENT STATUS!!Civilian labor force!!Unemployment Rate']

# %%
emp

# %%
col_df[col_df['2'] == 'INCOME AND BENEFITS '][0].to_list()
# Out:
# ['Estimate!!INCOME AND BENEFITS !!Total households',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!Less than $10,000',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!$10,000 to $14,999',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!$15,000 to $24,999',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!$25,000 to $34,999',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!$35,000 to $49,999',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!$50,000 to $74,999',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!$75,000 to $99,999',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!$100,000 to $149,999',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!$150,000 to $199,999',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!$200,000 or more',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!Median household income (dollars)',
#  'Estimate!!INCOME AND BENEFITS !!Total households!!Mean household income (dollars)',
# ...

# %%
income_list = [ 'Percent!!INCOME AND BENEFITS !!Total households!!Less than $10,000',
 'Percent!!INCOME AND BENEFITS !!Total households!!$10,000 to $14,999',
 'Percent!!INCOME AND BENEFITS !!Total households!!$15,000 to $24,999',
 'Percent!!INCOME AND BENEFITS !!Total households!!$25,000 to $34,999',
 'Percent!!INCOME AND BENEFITS !!Total households!!$35,000 to $49,999',
 'Percent!!INCOME AND BENEFITS !!Total households!!$50,000 to $74,999',
 'Percent!!INCOME AND BENEFITS !!Total households!!$75,000 to $99,999',
 'Percent!!INCOME AND BENEFITS !!Total households!!$100,000 to $149,999',
 'Percent!!INCOME AND BENEFITS !!Total households!!$150,000 to $199,999',
 'Percent!!INCOME AND BENEFITS !!Total households!!$200,000 or more',
 'Percent!!INCOME AND BENEFITS !!Total households!!With earnings',
 'Estimate!!INCOME AND BENEFITS !!Total households!!Median household income (dollars)',
 'Estimate!!INCOME AND BENEFITS !!Total households!!Mean household income (dollars)',

 'Estimate!!INCOME AND BENEFITS !!Total households!!With earnings!!Mean earnings (dollars)']

# %%
col_df[col_df['2'] == 'HEALTH INSURANCE COVERAGE'][0].to_list()
# Out:
# ['Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population',
#  'Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!With health insurance coverage',
#  'Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!With health insurance coverage!!With private health insurance',
#  'Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!With health insurance coverage!!With public coverage',
#  'Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!No health insurance coverage',
#  'Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population under 19 years',
#  'Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population under 19 years!!No health insurance coverage',
#  'Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population 19 to 64 years',
# ...

# %%
H_insr_list = [
 'Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!With health insurance coverage',
 'Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!With health insurance coverage!!With private health insurance',
 'Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!With health insurance coverage!!With public coverage',
 'Percent!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population!!No health insurance coverage']

# %%
col_df[col_df['2'] == 'PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL'][0].to_list()
# Out:
# ['Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families',
#  'Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!With related children of the householder under 18 years',
#  'Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!With related children of the householder under 18 years!!With related children of the householder under 5 years only',
#  'Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!Married couple families',
#  'Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!Married couple families!!With related children of the householder under 18 years',
# ...

# %%
poverty_list = ['Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people',
 'Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Under 18 years',

 'Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over!!18 to 64 years',
 'Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over!!65 years and over']

# %%
col_list = ['Geography', 'Geographic Area Name','Year']
col_list.extend(emp_list)
col_list.extend(income_list)
col_list.extend(H_insr_list)
col_list.extend(poverty_list)
col_list
# Out:
# ['Geography',
#  'Geographic Area Name',
#  'Year',
#  'Percent!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force',
#  'Percent!!EMPLOYMENT STATUS!!Civilian labor force!!Unemployment Rate',
#  'Percent!!INCOME AND BENEFITS !!Total households!!Less than $10,000',
#  'Percent!!INCOME AND BENEFITS !!Total households!!$10,000 to $14,999',
#  'Percent!!INCOME AND BENEFITS !!Total households!!$15,000 to $24,999',
#  'Percent!!INCOME AND BENEFITS !!Total households!!$25,000 to $34,999',
#  'Percent!!INCOME AND BENEFITS !!Total households!!$35,000 to $49,999',
#  'Percent!!INCOME AND BENEFITS !!Total households!!$50,000 to $74,999',
#  'Percent!!INCOME AND BENEFITS !!Total households!!$75,000 to $99,999',
#  'Percent!!INCOME AND BENEFITS !!Total households!!$100,000 to $149,999',
#  'Percent!!INCOME AND BENEFITS !!Total households!!$150,000 to $199,999',
#  'Percent!!INCOME AND BENEFITS !!Total households!!$200,000 or more',
# ...

# %%
comb_df2 = comb_df1[col_list]

comb_df2
# Out:
#           Geography       Geographic Area Name  Year  \
# 1    0500000US29001     Adair County, Missouri  2022
# 2    0500000US29003    Andrew County, Missouri  2022
# 3    0500000US29005  Atchison County, Missouri  2022
# 4    0500000US29007   Audrain County, Missouri  2022
# 5    0500000US29009     Barry County, Missouri  2022
# ..              ...                        ...   ...
# 111  0500000US29223     Wayne County, Missouri  2010
# 112  0500000US29225   Webster County, Missouri  2010
# 113  0500000US29227     Worth County, Missouri  2010
# 114  0500000US29229    Wright County, Missouri  2010
# 115  0500000US29510   St. Louis city, Missouri  2010
#
#      Percent!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                                 50.9
# 2                                                 63.1
# 3                                                 60.9
# 4                                                 57.9
# ...

# %%
def sum_missing_values(group):
    return group.isna().sum()
comb_df2.groupby('Year').apply(sum_missing_values)
# Out:
#       Geography  Geographic Area Name  Year  \
# Year
# 2010          0                     0     0
# 2011          0                     0     0
# 2012          0                     0     0
# 2013          0                     0     0
# 2014          0                     0     0
# 2015          0                     0     0
# 2016          0                     0     0
# 2017          0                     0     0
# 2018          0                     0     0
# 2019          0                     0     0
# 2020          0                     0     0
# 2021          0                     0     0
# 2022          0                     0     0
#
#       Percent!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# Year
# 2010                                                  0
# 2011                                                  0
# 2012                                                  0
# 2013                                                  0
# ...

# %%
comb_df2 =  comb_df2.sort_values(by = ['Geographic Area Name' , 'Year'] , ascending = [True , False] ).ffill()
comb_df2
# Out:
#           Geography     Geographic Area Name  Year  \
# 1    0500000US29001   Adair County, Missouri  2022
# 1    0500000US29001   Adair County, Missouri  2021
# 1    0500000US29001   Adair County, Missouri  2020
# 1    0500000US29001   Adair County, Missouri  2019
# 1    0500000US29001   Adair County, Missouri  2018
# ..              ...                      ...   ...
# 114  0500000US29229  Wright County, Missouri  2014
# 114  0500000US29229  Wright County, Missouri  2013
# 114  0500000US29229  Wright County, Missouri  2012
# 114  0500000US29229  Wright County, Missouri  2011
# 114  0500000US29229  Wright County, Missouri  2010
#
#      Percent!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                                 50.9
# 1                                                 51.6
# 1                                                 53.8
# 1                                                 53.4
# ...

# %%
comb_df2[comb_df2.iloc[:, 3:].columns] = comb_df2[comb_df2.iloc[:, 3:].columns].astype(float)

# %%
comb_df2.to_csv('DP03_final.csv' , index = False)

# %%
comb_df2
# Out:
#           Geography     Geographic Area Name  Year  \
# 1    0500000US29001   Adair County, Missouri  2022
# 1    0500000US29001   Adair County, Missouri  2021
# 1    0500000US29001   Adair County, Missouri  2020
# 1    0500000US29001   Adair County, Missouri  2019
# 1    0500000US29001   Adair County, Missouri  2018
# ..              ...                      ...   ...
# 114  0500000US29229  Wright County, Missouri  2014
# 114  0500000US29229  Wright County, Missouri  2013
# 114  0500000US29229  Wright County, Missouri  2012
# 114  0500000US29229  Wright County, Missouri  2011
# 114  0500000US29229  Wright County, Missouri  2010
#
#      Percent!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                                 50.9
# 1                                                 51.6
# 1                                                 53.8
# 1                                                 53.4
# ...

# %%
comb_df2.isna().sum()/comb_df2.shape[0]
# Out:
# Year                                                                                                                                                          0.0
# Percent!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force                                                                                      0.0
# Percent!!EMPLOYMENT STATUS!!Civilian labor force!!Unemployment Rate                                                                                           0.0
# Percent!!INCOME AND BENEFITS !!Total households!!Less than $10,000                                                                                            0.0
# Percent!!INCOME AND BENEFITS !!Total households!!$10,000 to $14,999                                                                                           0.0
# Percent!!INCOME AND BENEFITS !!Total households!!$15,000 to $24,999                                                                                           0.0
# ...

# %%
comb_df2.reset_index()
# Out:
#       index  Year  \
# 0         1  2022
# 1         2  2022
# 2         3  2022
# 3         4  2022
# 4         5  2022
# ...     ...   ...
# 1490    111  2010
# 1491    112  2010
# 1492    113  2010
# 1493    114  2010
# 1494    115  2010
#
#       Percent!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 0                                                  50.9
# 1                                                  63.1
# 2                                                  60.9
# 3                                                  57.9
# 4                                                  55.9
# ...                                                 ...
# 1490                                               52.1
# 1491                                               60.1
# 1492                                               65.0
# 1493                                               53.1
# 1494                                               65.9
#
# ...

# %%
pd.set_option('display.max_rows', 500)  
pd.set_option('display.max_columns', 500)
