# %%
import pandas as pd , numpy as np

# %%
data = pd.read_csv('Rates_and_Trends.csv')
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5770240 entries, 0 to 5770239
# Data columns (total 21 columns):
# Year                          object
# LocationAbbr                  object
# LocationDesc                  object
# GeographicLevel               object
# DataSource                    object
# Class                         object
# Topic                         object
# Data_Value                    float64
# Data_Value_Unit               object
# Data_Value_Type               object
# Data_Value_Footnote_Symbol    object
# Data_Value_Footnote           object
# Confidence_limit_Low          float64
# Confidence_limit_High         float64
# StratificationCategory1       object
# Stratification1               object
# StratificationCategory2       object
# Stratification2               object
# StratificationCategory3       object
# Stratification3               object
# LocationID                    int64
# dtypes: float64(3), int64(1), object(17)
# ...

# %%
data.head()
# Out:
#    Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 0  1999           AL      Autauga          County       NVSS
# 1  2013           AL      Autauga          County       NVSS
# 2  2014           AL      Autauga          County       NVSS
# 3  2005           AL      Autauga          County       NVSS
# 4  2012           AL      Autauga          County       NVSS
#
#                      Class              Topic  Data_Value Data_Value_Unit  \
# 0  Cardiovascular Diseases  All heart disease         NaN     per 100,000
# 1  Cardiovascular Diseases  All heart disease         NaN     per 100,000
# 2  Cardiovascular Diseases  All heart disease         NaN     per 100,000
# 3  Cardiovascular Diseases  All heart disease         NaN     per 100,000
# 4  Cardiovascular Diseases  All heart disease         NaN     per 100,000
#
#                                     Data_Value_Type  ... Data_Value_Footnote  \
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                 Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 0               1999           AL      Autauga          County       NVSS
# 1               2013           AL      Autauga          County       NVSS
# 2               2014           AL      Autauga          County       NVSS
# 3               2005           AL      Autauga          County       NVSS
# 4               2012           AL      Autauga          County       NVSS
# ...              ...          ...          ...             ...        ...
# 5770235  1999 - 2010           WY       Weston          County       NVSS
# 5770236  2010 - 2019           WY       Weston          County       NVSS
# 5770237  1999 - 2010           WY       Weston          County       NVSS
# 5770238  1999 - 2010           WY       Weston          County       NVSS
# 5770239  2010 - 2019           WY       Weston          County       NVSS
#
# ...

# %%
data = data[data['LocationAbbr'] == 'MO']

# %%
data.shape
# Out:
# (211600, 21)

# %%
for col in data.columns:
    print('\n{}:\n'.format(col))
    print(data[col].describe())
# Out:
# Year:
#
# count          211600
# unique             23
# top       2010 - 2019
# freq             9200
# Name: Year, dtype: object
#
# LocationAbbr:
#
# count     211600
# unique         1
# top           MO
# freq      211600
# Name: LocationAbbr, dtype: object
#
# LocationDesc:
#
# count        211600
# unique          114
# top       St. Louis
# freq           3680
# Name: LocationDesc, dtype: object
#
# GeographicLevel:
#
# count     211600
# unique         1
# top       County
# freq      211600
# Name: GeographicLevel, dtype: object
#
# DataSource:
#
# count     211600
# unique         1
# top         NVSS
# freq      211600
# Name: DataSource, dtype: object
#
# Class:
#
# count                      211600
# unique                          1
# top       Cardiovascular Diseases
# freq                       211600
# Name: Class, dtype: object
#
# Topic:
#
# count                           211600
# unique                               5
# top       Cardiovascular disease (CVD)
# ...

# %%
for col in data.columns:
    print('\n{}:\n'.format(col))
    print(data[col].value_counts())
    print('Null Values: ',data[col].isna().sum())
    print('Null Values percentage: ',round((data[col].isna().sum()/data.shape[0])*100 , 2))
# Out:
# Year:
#
# 2010 - 2019    9200
# 2009           9200
# 2000           9200
# 2001           9200
# 2002           9200
# 2003           9200
# 2004           9200
# 2005           9200
# 2006           9200
# 2007           9200
# 2008           9200
# 2010           9200
# 1999 - 2010    9200
# 2011           9200
# 2012           9200
# 2013           9200
# 2014           9200
# 2015           9200
# 2016           9200
# 2017           9200
# 2018           9200
# 2019           9200
# 1999           9200
# Name: Year, dtype: int64
# Null Values:  0
# Null Values percentage:  0.0
#
# LocationAbbr:
#
# MO    211600
# Name: LocationAbbr, dtype: int64
# Null Values:  0
# Null Values percentage:  0.0
#
# LocationDesc:
#
# St. Louis    3680
# Dunklin      1840
# Clark        1840
# Dallas       1840
# Johnson      1840
#              ...
# Lafayette    1840
# Cole         1840
# Mercer       1840
# Vernon       1840
# Wright       1840
# Name: LocationDesc, Length: 114, dtype: int64
# ...

# %%
data.sort_values(by= ['Year','LocationDesc', 'Topic' , 'Data_Value_Type' ] , ascending  = True , inplace = True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.head(1000)
# Out:
#          Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 2481364  1999           MO        Adair          County       NVSS
# 2481488  1999           MO        Adair          County       NVSS
# 2481595  1999           MO        Adair          County       NVSS
# 2481699  1999           MO        Adair          County       NVSS
# 2481797  1999           MO        Adair          County       NVSS
# ...       ...          ...          ...             ...        ...
# 2501918  1999           MO     Caldwell          County       NVSS
# 2502007  1999           MO     Caldwell          County       NVSS
# 2502123  1999           MO     Caldwell          County       NVSS
# 2502225  1999           MO     Caldwell          County       NVSS
# 2502338  1999           MO     Caldwell          County       NVSS
#
#                            Class                         Topic  Data_Value  \
# 2481364  Cardiovascular Diseases             All heart disease         NaN
# ...

# %%
#St. Louis City	510
#St. Louis Cnty	189

# %%
data[data['LocationDesc'] == 'St. Louis']['LocationID'].value_counts()
# Out:
# 29189    1840
# 29510    1840
# Name: LocationID, dtype: int64

# %%
data.loc[data['LocationID'] == '29510' , 'LocationDesc'] = 'St. Louis City'
data.loc[data['LocationID'] == '29189' , 'LocationDesc'] = 'St Louis'
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
data.drop(['LocationAbbr' , 'GeographicLevel','DataSource','Class'] , axis = 1 , inplace  = True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data.head(1000)
# Out:
#          Year LocationDesc                         Topic  Data_Value  \
# 2481364  1999        Adair             All heart disease         NaN
# 2481488  1999        Adair             All heart disease       135.2
# 2481595  1999        Adair             All heart disease        85.9
# 2481699  1999        Adair             All heart disease       196.7
# 2481797  1999        Adair             All heart disease         NaN
# ...       ...          ...                           ...         ...
# 2501918  1999     Caldwell  Cardiovascular disease (CVD)       230.5
# 2502007  1999     Caldwell  Cardiovascular disease (CVD)         NaN
# 2502123  1999     Caldwell  Cardiovascular disease (CVD)         NaN
# 2502225  1999     Caldwell  Cardiovascular disease (CVD)         NaN
# 2502338  1999     Caldwell  Cardiovascular disease (CVD)       156.0
#
#         Data_Value_Unit                                   Data_Value_Type  \
# ...

# %%
data[(data['Year'] == '2010 - 2019') & (data['Topic'] == 'All stroke')]
# Out:
#                 Year LocationDesc       Topic  Data_Value Data_Value_Unit  \
# 5504818  2010 - 2019        Adair  All stroke         NaN               %
# 5504828  2010 - 2019        Adair  All stroke         5.4               %
# 5504837  2010 - 2019        Adair  All stroke         5.3               %
# 5504847  2010 - 2019        Adair  All stroke         3.6               %
# 5504857  2010 - 2019        Adair  All stroke         NaN               %
# ...              ...          ...         ...         ...             ...
# 5523003  2010 - 2019       Wright  All stroke       -18.5               %
# 5523013  2010 - 2019       Wright  All stroke         NaN               %
# 5523024  2010 - 2019       Wright  All stroke         NaN               %
# 5523033  2010 - 2019       Wright  All stroke         NaN               %
# 5523043  2010 - 2019       Wright  All stroke       -17.6               %
#
#               Data_Value_Type Data_Value_Footnote_Symbol Data_Value_Footnote  \
# ...

# %%
data = data[~(data['Year'].isin(['1999 - 2010' , '2010 - 2019']))]
data = data[data['Topic'] == 'All stroke']

# %%
data['Year'] = data['Year'].astype(str).str.replace(' ' , '')

# %%
data.Year.value_counts()
# Out:
# 2009    1840
# 2002    1840
# 2001    1840
# 2017    1840
# 2014    1840
# 2018    1840
# 2013    1840
# 2012    1840
# 2007    1840
# 2011    1840
# 2019    1840
# 2005    1840
# 2016    1840
# 2003    1840
# 2004    1840
# 2010    1840
# 1999    1840
# 2008    1840
# 2006    1840
# 2015    1840
# 2000    1840
# Name: Year, dtype: int64

# %%
data['Year'] = data['Year'].astype(int)

# %%
#data = data[~(data['Year'].isin(['1999','2000','2001' , '2002' , '2003' , '2004']))]
data = data[data['Year'] >= 2005]

# %%
data.Year.isna().sum()
# Out:
# 0

# %%
data
# Out:
#          Year LocationDesc       Topic  Data_Value Data_Value_Unit  \
# 2480606  2005        Adair  All stroke        17.4     per 100,000
# 2481390  2005        Adair  All stroke         NaN     per 100,000
# 2481500  2005        Adair  All stroke        17.6     per 100,000
# 2481604  2005        Adair  All stroke        13.6     per 100,000
# 2481818  2005        Adair  All stroke         NaN     per 100,000
# ...       ...          ...         ...         ...             ...
# 2672393  2019       Wright  All stroke       257.2     per 100,000
# 2672483  2019       Wright  All stroke         NaN     per 100,000
# 2672593  2019       Wright  All stroke         NaN     per 100,000
# 2672695  2019       Wright  All stroke         NaN     per 100,000
# 2672804  2019       Wright  All stroke       245.1     per 100,000
#
#                                           Data_Value_Type  \
# 2480606  Age-Standardized, Spatiotemporally Smoothed Rate
# ...

# %%
data[data['Data_Value_Footnote'].notna()].groupby(['Data_Value_Footnote']).agg(
    {'Stratification1': 'value_counts' , 'Stratification2': 'value_counts' , 'Stratification3': 'value_counts'})
# Out:
#                                                 Stratification1  \
# Value suppressed Ages 35-64 years                        5820.0
#                  Ages 65 years and older                 6750.0
#                  American Indian/Alaska Native              NaN
#                  Asian/Pacific Islander                     NaN
#                  Black (Non-Hispanic)                       NaN
#                  Hispanic                                   NaN
#                  Men                                        NaN
#                  Overall                                    NaN
#                  Women                                      NaN
#
#                                                 Stratification2  \
# Value suppressed Ages 35-64 years                           NaN
#                  Ages 65 years and older                    NaN
#                  American Indian/Alaska Native           3360.0
#                  Asian/Pacific Islander                  3165.0
# ...

# %%
Overall                          79350
Hispanic                         26450
American Indian/Alaska Native    26450
White                            26450
Asian/Pacific Islander           26450
Black (Non-Hispanic)
# Out:
#   File "<ipython-input-26-81080c5fd5b3>", line 1
#     Overall                          79350
#                                          ^
# SyntaxError: invalid syntax

# %%
check = data[(data['LocationDesc'] == 'Adair') & (data['Year'] == 2010) & (data['Topic'] == 'All stroke')]

# %%
check

# %%
ovr_data = data[(data['Stratification2'] == 'Overall') & (data['Stratification3'] == 'Overall')]

# %%
ovr_data.Data_Value.isna().sum()
# Out:
# 0

# %%
ovr_data[ovr_data['Data_Value_Footnote'].notna()].groupby(['Data_Value_Footnote']).agg(
    {'Stratification1': 'value_counts' , 'Stratification2': 'value_counts' , 'Stratification3': 'value_counts'})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-9bcc0a12b4e4> in <module>
#       1 ovr_data[ovr_data['Data_Value_Footnote'].notna()].groupby(['Data_Value_Footnote']).agg(
# ----> 2     {'Stratification1': 'value_counts' , 'Stratification2': 'value_counts' , 'Stratification3': 'value_counts'})
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# ...

# %%
data.shape
# Out:
# (27600, 17)

# %%
ovr_data.shape
# Out:
# (3450, 17)

# %%
data
# Out:
#          Year LocationDesc       Topic  Data_Value Data_Value_Unit  \
# 2480606  2005        Adair  All stroke        17.4     per 100,000
# 2481390  2005        Adair  All stroke         NaN     per 100,000
# 2481500  2005        Adair  All stroke        17.6     per 100,000
# 2481604  2005        Adair  All stroke        13.6     per 100,000
# 2481818  2005        Adair  All stroke         NaN     per 100,000
# ...       ...          ...         ...         ...             ...
# 2672393  2019       Wright  All stroke       257.2     per 100,000
# 2672483  2019       Wright  All stroke         NaN     per 100,000
# 2672593  2019       Wright  All stroke         NaN     per 100,000
# 2672695  2019       Wright  All stroke         NaN     per 100,000
# 2672804  2019       Wright  All stroke       245.1     per 100,000
#
#                                           Data_Value_Type  \
# 2480606  Age-Standardized, Spatiotemporally Smoothed Rate
# ...

# %%
ovr_data65older = ovr_data[ovr_data['Stratification1'] == 'Ages 65 years and older']

# %%
ovr_data65older.Year.value_counts()
# Out:
# 2019    115
# 2018    115
# 2017    115
# 2016    115
# 2015    115
# 2014    115
# 2013    115
# 2012    115
# 2011    115
# 2010    115
# 2009    115
# 2008    115
# 2007    115
# 2006    115
# 2005    115
# Name: Year, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(ovr_data65older['Year'], ovr_data65older['Data_Value'])

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart')

# Display the plot
plt.show()

# %%
plt.hist(ovr_data65older['Data_Value'], bins=15, color='orange', edgecolor='black')

# Add labels and title
plt.xlabel('Stroke Mortality Rate')
plt.ylabel('Frequency')
plt.title('Stroke Mortality Distribution 2005 - 2019')
# Out:
# Text(0.5, 1.0, 'Stroke Mortality Distribution 2005 - 2019')

# %%
#ovr_data65older.to_csv('StrokeMortality65older2005_2019.csv' , index = False)

# %%
ovr_data.Year.value_counts()
# Out:
# 2019    115
# 2018    115
# 2017    115
# 2016    115
# 2015    115
# 2014    115
# 2013    115
# 2012    115
# 2011    115
# 2010    115
# 2009    115
# 2008    115
# 2007    115
# 2006    115
# 2005    115
# Name: Year, dtype: int64

# %%
from plotnine import *

# %%
ovr_data
# Out:
#          Year LocationDesc       Topic  Data_Value Data_Value_Unit  \
# 2482330  2005        Adair  All stroke       387.3     per 100,000
# 2484009  2005       Andrew  All stroke       420.2     per 100,000
# 2485689  2005     Atchison  All stroke       469.8     per 100,000
# 2487373  2005      Audrain  All stroke       340.7     per 100,000
# 2489051  2005        Barry  All stroke       463.0     per 100,000
# ...       ...          ...         ...         ...             ...
# 2665463  2019   Washington  All stroke       239.9     per 100,000
# 2667136  2019        Wayne  All stroke       277.0     per 100,000
# 2668817  2019      Webster  All stroke       258.4     per 100,000
# 2670496  2019        Worth  All stroke       228.0     per 100,000
# 2672175  2019       Wright  All stroke       243.6     per 100,000
#
#                                           Data_Value_Type  \
# 2482330  Age-Standardized, Spatiotemporally Smoothed Rate
# ...

# %%
boxplot = ggplot(ovr_data, aes("factor(Year)", "Data_Value", fill="factor(Stratification1)"))+ geom_boxplot()+theme_minimal()+labs(y = 'Stroke Mortality Rate' , x = 'Year' , color = "Age Range"  )

# %%
boxplot
# Out:
# <ggplot: (8764879571369)>

# %%
age_avg = ovr_data.groupby(['Year', 'Stratification1']).agg(mean = ('Data_Value','mean' ),median = ('Data_Value','median' )).reset_index()

# %%
display(age_avg)
# Out:
#     Year          Stratification1        mean  median
# 0   2005         Ages 35-64 years   17.795652    17.5
# 1   2005  Ages 65 years and older  391.317391   381.1
# 2   2006         Ages 35-64 years   17.980000    17.5
# 3   2006  Ages 65 years and older  368.811304   362.6
# 4   2007         Ages 35-64 years   17.781739    17.2
# 5   2007  Ages 65 years and older  361.942609   358.3
# 6   2008         Ages 35-64 years   17.233913    16.7
# 7   2008  Ages 65 years and older  363.342609   357.3
# 8   2009         Ages 35-64 years   17.042609    16.6
# 9   2009  Ages 65 years and older  330.062609   323.8
# 10  2010         Ages 35-64 years   16.105217    15.5
# 11  2010  Ages 65 years and older  323.921739   315.5
# 12  2011         Ages 35-64 years   16.812174    16.4
# 13  2011  Ages 65 years and older  314.406957   304.7
# 14  2012         Ages 35-64 years   16.770435    16.3
# 15  2012  Ages 65 years and older  303.793913   293.6
# ...

# %%
lineplot = ggplot(age_avg, aes("Year", "median", color="factor(Stratification1)"))+geom_point()+ geom_line()+labs(y = 'Median Stroke Mrtality'  )+theme_minimal()+\
scale_x_continuous()
lineplot
# Out:
# <ggplot: (8764966177221)>

# %%
data.columns
# Out:
# Index(['Year', 'LocationDesc', 'Topic', 'Data_Value', 'Data_Value_Unit',
#        'Data_Value_Type', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Confidence_limit_Low', 'Confidence_limit_High',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'LocationID'],
#       dtype='object')

# %%
ovr_data1 = data[(data['Stratification3'] == 'Overall')]

# %%
ovr_data1.Year.value_counts()
# Out:
# 2015    1380
# 2014    1380
# 2013    1380
# 2012    1380
# 2011    1380
# 2010    1380
# 2009    1380
# 2008    1380
# 2007    1380
# 2006    1380
# 2005    1380
# 2019    1380
# 2018    1380
# 2017    1380
# 2016    1380
# Name: Year, dtype: int64

# %%
age_avg1 = ovr_data1.groupby(['Year', 'Stratification1' , 'Stratification2']).agg(mean = ('Data_Value','mean' ),median = ('Data_Value','median' )).reset_index()

# %%
age_avg1 = age_avg1[age_avg1['Stratification2'] != 'American Indian/Alaska Native']

# %%
lineplot1 = ggplot(age_avg1, aes("Year", "median", color="factor(Stratification2)"))+geom_point()+ geom_line()+labs(y = 'Median Stroke Mortality' , color = 'Race'  )+ facet_wrap("Stratification1")+theme_minimal()+ scale_y_continuous(limits = (0, 600))+scale_x_continuous(limits = (2005, 2019))
lineplot1
# Out:
# <ggplot: (-9223363271893849691)>

# %%
ovr_data2 = data[(data['Stratification2'] == 'Overall')]

# %%
ovr_data2.Year.value_counts()
# Out:
# 2015    690
# 2007    690
# 2014    690
# 2006    690
# 2013    690
# 2005    690
# 2012    690
# 2019    690
# 2011    690
# 2018    690
# 2010    690
# 2017    690
# 2009    690
# 2016    690
# 2008    690
# Name: Year, dtype: int64

# %%
age_avg2 = ovr_data2.groupby(['Year', 'Stratification1' , 'Stratification3']).agg(mean = ('Data_Value','mean' ),median = ('Data_Value','median' )).reset_index()

# %%
age_avg2
# Out:
#     Year          Stratification1 Stratification3        mean  median
# 0   2005         Ages 35-64 years             Men   19.603509   18.80
# 1   2005         Ages 35-64 years         Overall   17.795652   17.50
# 2   2005         Ages 35-64 years           Women   15.898246   15.25
# 3   2005  Ages 65 years and older             Men  378.432727  369.10
# 4   2005  Ages 65 years and older         Overall  391.317391  381.10
# ..   ...                      ...             ...         ...     ...
# 85  2019         Ages 35-64 years         Overall   17.109565   16.70
# 86  2019         Ages 35-64 years           Women   14.578070   14.50
# 87  2019  Ages 65 years and older             Men  253.303636  248.05
# 88  2019  Ages 65 years and older         Overall  260.982609  256.70
# 89  2019  Ages 65 years and older           Women  259.441818  258.25
#
# [90 rows x 5 columns]

# %%
lineplot1 = ggplot(age_avg2, aes("Year", "median", color="factor(Stratification3)"))+geom_point()+ geom_line()+labs(y = 'Median Stroke Mrtality'  )+ facet_wrap("Stratification1")+theme_minimal()+scale_y_continuous(limits = (0, 600))
lineplot1
# Out:
# <ggplot: (-9223363271893744780)>
